# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
utilization = pd.read_csv('bw_utilization.csv')
plot = plt.plot(utilization['TS'], utilization['L1'], '', utilization['L2'], '', utilization['L3'], '')

# %%
sample = utilization[ :100]
sample

plot = plt.plot(sample['TS'], sample['L1'], '', sample['L2'], '', sample['L3'], '')

# %%
L1 = sample['L1']

# %%
L1_mean = pd.rolling_mean(L1, window=10)

# %%
pd.rolling_corr(sample.L1, sample.L2, window=10).plot(style='-g')

# %%
import numpy
numpy.fft.fft(L1)
# Out:
# array([  6.76870443e+01 +0.00000000e+00j,
#         -8.92706895e-01 +7.87717748e+00j,
#         -3.53948450e-01 +3.63531095e+00j,
#          1.06360845e-02 +2.58079819e+00j,
#         -6.02651119e-01 +1.26387437e+00j,
#         -1.15831492e-01 +1.36494368e+00j,
#         -7.82134960e-01 +1.17325706e+00j,
#         -1.37013030e-01 +9.93403395e-01j,
#          1.41119146e-01 +1.03893580e+00j,
#         -9.06306234e-02 +8.95077945e-01j,
#         -5.04021428e-01 +8.41287112e-01j,
#         -1.15748352e-02 +1.28425148e-01j,
#         -1.17166307e-01 +8.70250446e-01j,
#         -4.51956664e-02 +3.58853744e-01j,
#         -7.34560352e-01 +5.86246695e-01j,
#         -4.63617678e-01 +1.51005477e-01j,
#         -3.51557395e-01 +5.89659133e-01j,
#         -1.06586211e-01 +4.21172117e-01j,
#         -4.03385169e-01 +4.16344056e-01j,
#         -1.60658673e-01 +4.49174182e-01j,
#         -4.05266016e-01 +3.47652035e-01j,
#         -1.44136797e-01 +3.46019154e-01j,
# ...
